# %%
import os
import json
import pandas as pd
import matplotlib.pyplot as plt

# %%
ROOT = 'C:\\Users\\niti.mishra\\Documents\\Personal\\cyberbullying\\'
RESULTS = os.path.join(ROOT, 'results')
PLOTS = os.path.join(RESULTS, 'fig')
file = RESULTS+'\\results_3g.json'

df = pd.read_json(file, lines=True)
df
# Out:
#                                                model  \
# 0  Pipeline(memory=None,\n         steps=[('norma...
# 1  Pipeline(memory=None,\n         steps=[('norma...
# 2  Pipeline(memory=None,\n         steps=[('norma...
# 3  Pipeline(memory=None,\n         steps=[('norma...
# 4  Pipeline(memory=None,\n         steps=[('norma...
# 5  Pipeline(memory=None,\n         steps=[('norma...
#
#                                 name  \
# 0  LogisticRegression (TruncatedSVD)
# 1                 LogisticRegression
# 2       SGDClassifier (TruncatedSVD)
# 3                      SGDClassifier
# 4                      MultinomialNB
# 5          GaussianNB (TruncatedSVD)
#
#                                             accuracy  \
# 0  [0.660975609756097, 0.660975609756097, 0.67073...
# 1  [0.692682926829268, 0.675609756097561, 0.67804...
# 2  [0.6658536585365851, 0.697560975609756, 0.6463...
# 3  [0.646341463414634, 0.692682926829268, 0.68780...
# 4  [0.658536585365853, 0.6853658536585361, 0.6341...
# 5  [0.5634146341463411, 0.536585365853658, 0.5975...
#
#                                            precision  \
# 0  [0.6588997378899131, 0.658686223496117, 0.6671...
# 1  [0.693095754500614, 0.6829086606768451, 0.6904...
# 2  [0.6643766209167461, 0.6947342334780271, 0.645...
# 3  [0.6514751286346301, 0.69123277083292, 0.68634...
# 4  [0.709294660514172, 0.723074010421571, 0.65031...
# 5  [0.5171311921996501, 0.51156762325965, 0.56290...
#
#                                               recall  \
# 0  [0.660975609756097, 0.660975609756097, 0.67073...
# 1  [0.692682926829268, 0.675609756097561, 0.67804...
# 2  [0.6658536585365851, 0.697560975609756, 0.6463...
# 3  [0.646341463414634, 0.692682926829268, 0.68780...
# 4  [0.658536585365853, 0.6853658536585361, 0.6341...
# 5  [0.5634146341463411, 0.536585365853658, 0.5975...
#
#                                                   f1  \
# 0  [0.6345511249384991, 0.6401366354101891, 0.654...
# 1  [0.679726423028706, 0.659141401369263, 0.66066...
# 2  [0.665015908715844, 0.683783456539601, 0.64597...
# 3  [0.648449786539215, 0.6908894654903991, 0.6869...
# 4  [0.619136960600375, 0.6493811734057671, 0.5964...
# 5  [0.45590569258879404, 0.418416359871145, 0.501...
#
#                                                 time
# 0  [22.141072988510132, 20.00481653213501, 20.902...
# 1  [1.443198204040527, 1.327456474304199, 1.38829...
# 2  [21.173570156097412, 21.37788224220276, 21.951...
# 3  [1.209293842315673, 1.195791959762573, 1.22877...
# 4  [1.148935079574585, 1.459189414978027, 1.20579...
# 5  [20.670536279678345, 22.97279167175293, 22.487...

# %%
new_df = pd.DataFrame(columns=df.columns[1:])
new_df['name'] = df.name

for i in df.columns[2:]:
    nes_ls = df[i].values.tolist()
    avg = [sum(ls)/len(ls) for ls in nes_ls]
    new_df[i] = pd.Series(avg)
new_df
# Out:
#                                 name  accuracy  precision    recall        f1  \
# 0  LogisticRegression (TruncatedSVD)  0.668579   0.674068  0.668579  0.646387
# 1                 LogisticRegression  0.683605   0.688118  0.683605  0.666008
# 2       SGDClassifier (TruncatedSVD)  0.677516   0.679988  0.677516  0.670778
# 3                      SGDClassifier  0.672224   0.673958  0.672224  0.672611
# 4                      MultinomialNB  0.658604   0.683318  0.658604  0.617365
# 5          GaussianNB (TruncatedSVD)  0.583096   0.569303  0.583096  0.475728
#
#         time
# 0  21.259994
# 1   1.379376
# 2  21.764834
# 3   1.317908
# 4   1.303536
# 5  21.688699

# %%
sub_df = df.drop('model', axis=1) 
sub_df
# Out:
#                                 name  \
# 0  LogisticRegression (TruncatedSVD)
# 1                 LogisticRegression
# 2       SGDClassifier (TruncatedSVD)
# 3                      SGDClassifier
# 4                      MultinomialNB
# 5          GaussianNB (TruncatedSVD)
#
#                                             accuracy  \
# 0  [0.660975609756097, 0.660975609756097, 0.67073...
# 1  [0.692682926829268, 0.675609756097561, 0.67804...
# 2  [0.6658536585365851, 0.697560975609756, 0.6463...
# 3  [0.646341463414634, 0.692682926829268, 0.68780...
# 4  [0.658536585365853, 0.6853658536585361, 0.6341...
# 5  [0.5634146341463411, 0.536585365853658, 0.5975...
#
#                                            precision  \
# 0  [0.6588997378899131, 0.658686223496117, 0.6671...
# 1  [0.693095754500614, 0.6829086606768451, 0.6904...
# 2  [0.6643766209167461, 0.6947342334780271, 0.645...
# 3  [0.6514751286346301, 0.69123277083292, 0.68634...
# 4  [0.709294660514172, 0.723074010421571, 0.65031...
# 5  [0.5171311921996501, 0.51156762325965, 0.56290...
#
#                                               recall  \
# 0  [0.660975609756097, 0.660975609756097, 0.67073...
# 1  [0.692682926829268, 0.675609756097561, 0.67804...
# 2  [0.6658536585365851, 0.697560975609756, 0.6463...
# 3  [0.646341463414634, 0.692682926829268, 0.68780...
# 4  [0.658536585365853, 0.6853658536585361, 0.6341...
# 5  [0.5634146341463411, 0.536585365853658, 0.5975...
#
#                                                   f1  \
# 0  [0.6345511249384991, 0.6401366354101891, 0.654...
# 1  [0.679726423028706, 0.659141401369263, 0.66066...
# 2  [0.665015908715844, 0.683783456539601, 0.64597...
# 3  [0.648449786539215, 0.6908894654903991, 0.6869...
# 4  [0.619136960600375, 0.6493811734057671, 0.5964...
# 5  [0.45590569258879404, 0.418416359871145, 0.501...
#
#                                                 time
# 0  [22.141072988510132, 20.00481653213501, 20.902...
# 1  [1.443198204040527, 1.327456474304199, 1.38829...
# 2  [21.173570156097412, 21.37788224220276, 21.951...
# 3  [1.209293842315673, 1.195791959762573, 1.22877...
# 4  [1.148935079574585, 1.459189414978027, 1.20579...
# 5  [20.670536279678345, 22.97279167175293, 22.487...

# %%
df_lists = sub_df[['accuracy','precision','recall','f1','time']].unstack().apply(pd.Series)

# %%
score = 'f1'
plot_data = df_lists.T[score]
plot_data.columns = list(df.name)
plot_data.index = range(1,13)
plot_data
# Out:
#     LogisticRegression (TruncatedSVD)  LogisticRegression  \
# 1                            0.634551            0.679726
# 2                            0.640137            0.659141
# 3                            0.654746            0.660661
# 4                            0.579353            0.724410
# 5                            0.651351            0.671915
# 6                            0.629653            0.672222
# 7                            0.669167            0.686183
# 8                            0.638315            0.639678
# 9                            0.638290            0.664564
# 10                           0.664860            0.639718
# 11                           0.671643            0.617965
# 12                           0.684581            0.675909
#
#     SGDClassifier (TruncatedSVD)  SGDClassifier  MultinomialNB  \
# 1                       0.665016       0.648450       0.619137
# 2                       0.683783       0.690889       0.649381
# 3                       0.645975       0.686928       0.596455
# 4                       0.680942       0.662954       0.617440
# 5                       0.711641       0.678049       0.574992
# 6                       0.656536       0.698741       0.623977
# 7                       0.679982       0.660701       0.598706
# 8                       0.670424       0.686023       0.581370
# 9                       0.692525       0.698386       0.643325
# 10                      0.686369       0.645954       0.621630
# 11                      0.618317       0.632566       0.656182
# 12                      0.657828       0.681694       0.625783
#
#     GaussianNB (TruncatedSVD)
# 1                    0.455906
# 2                    0.418416
# 3                    0.501719
# 4                    0.476566
# 5                    0.525671
# 6                    0.543473
# 7                    0.516882
# 8                    0.490093
# 9                    0.478999
# 10                   0.456434
# 11                   0.407925
# 12                   0.436657

# %%
import pandas as pd
import numpy as np
# %matplotlib inline 
plt.rcParams['figure.figsize'] = [10, 5]
#f, ax = plt.subplots()
ax = plot_data.plot(style='.-')
plt.ylabel(score)
plt.xlabel('CV fold')
plt.title('{} score of each classifier over CV fold on (3,3) gram model'.format(score, gram))
# plt.show()
plt.savefig(PLOTS+'\\f1_3g.png', bbox_inches='tight')

# %%
df.name
# Out:
# 0    LogisticRegression (TruncatedSVD)
# 1                   LogisticRegression
# 2         SGDClassifier (TruncatedSVD)
# 3                        SGDClassifier
# 4                        MultinomialNB
# 5            GaussianNB (TruncatedSVD)
# Name: name, dtype: object
