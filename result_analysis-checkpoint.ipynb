# %%
import os
import json
import re
import pandas as pd
import matplotlib.pyplot as plt

# %%
ROOT = 'C:\\Users\\niti.mishra\\Documents\\Personal\\cyberbullying\\'
RESULTS = os.path.join(ROOT, 'results')
PLOTS = os.path.join(RESULTS) #, 'fig')
file = RESULTS+'\\TRACE_results491.json'

df = pd.read_json(file, lines=True)
df
# Out:
#                                                model  \
# 0  Pipeline(memory=None,\n         steps=[('norma...
# 1  Pipeline(memory=None,\n         steps=[('norma...
# 2  Pipeline(memory=None,\n         steps=[('norma...
# 3  Pipeline(memory=None,\n         steps=[('norma...
# 4  Pipeline(memory=None,\n         steps=[('norma...
# 5  Pipeline(memory=None,\n         steps=[('norma...
# 6  Pipeline(memory=None,\n         steps=[('norma...
#
#                                 name  \
# 0  LogisticRegression (TruncatedSVD)
# 1                 LogisticRegression
# 2       SGDClassifier (TruncatedSVD)
# 3                      SGDClassifier
# 4                                SVC
# 5                      MultinomialNB
# 6          GaussianNB (TruncatedSVD)
#
#                                             accuracy  \
# 0  [0.5975609756097561, 0.607317073170731, 0.6000...
# 1  [0.592682926829268, 0.6121951219512191, 0.5902...
# 2  [0.639024390243902, 0.6341463414634141, 0.6195...
# 3  [0.646341463414634, 0.626829268292682, 0.69024...
# 4  [0.658536585365853, 0.64390243902439, 0.646341...
# 5  [0.5609756097560971, 0.6121951219512191, 0.629...
# 6  [0.5829268292682921, 0.57560975609756, 0.55365...
#
#                                            precision  \
# 0  [0.619963763066202, 0.6045569620253161, 0.7294...
# 1  [0.641508288459507, 0.6434515302471561, 0.6726...
# 2  [0.6555602475427741, 0.615252032520325, 0.6615...
# 3  [0.6411106694107991, 0.622769175803992, 0.6862...
# 4  [0.664889893932051, 0.65393384092571, 0.639793...
# 5  [0.314693634741225, 0.763324964131994, 0.76704...
# 6  [0.5772265748732971, 0.594242546651622, 0.5475...
#
#                                               recall  \
# 0  [0.5975609756097561, 0.607317073170731, 0.6000...
# 1  [0.592682926829268, 0.6121951219512191, 0.5902...
# 2  [0.639024390243902, 0.6341463414634141, 0.6195...
# 3  [0.646341463414634, 0.626829268292682, 0.69024...
# 4  [0.658536585365853, 0.64390243902439, 0.646341...
# 5  [0.5609756097560971, 0.6121951219512191, 0.629...
# 6  [0.5829268292682921, 0.57560975609756, 0.55365...
#
#                                                   f1  \
# 0  [0.5096845206539521, 0.489521435606027, 0.4967...
# 1  [0.47067465230751304, 0.52454491374182, 0.4858...
# 2  [0.598381344980451, 0.5816919658422101, 0.5779...
# 3  [0.642009755730447, 0.6206543794679801, 0.6856...
# 4  [0.6389602053915271, 0.608199949186991, 0.6069...
# 5  [0.403201219512195, 0.469977186031209, 0.48861...
# 6  [0.5782448409252311, 0.579480442845903, 0.5496...
#
#                                                 time
# 0  [3.879927158355713, 2.700082540512085, 2.68963...
# 1  [0.25113797187805104, 0.271443605422973, 0.289...
# 2  [3.080055713653564, 2.916207075119018, 2.98004...
# 3  [0.31986904144287104, 0.440057516098022, 0.309...
# 4  [0.380090713500976, 0.444923877716064, 0.39995...
# 5  [0.217525720596313, 0.24618411064147902, 0.270...
# 6  [3.154996633529663, 3.4166829586029053, 3.2324...

# %%
new_df = pd.DataFrame(columns=df.columns[1:])
new_df['name'] = df.name

for i in df.columns[2:7]:
    nes_ls = df[i].values.tolist()
    avg = [sum(ls)/len(ls) for ls in nes_ls]
    new_df[i] = pd.Series(avg)
new_df['trainingsize'] = str(re.search(r'\d\d\d', file).group())

# %%
file = RESULTS+'\\TRACE_results1597.json'
df = pd.read_json(file, lines=True)

plot_df = new_df.copy()

new_df = pd.DataFrame(columns=df.columns[1:])
new_df['name'] = df.name
for i in df.columns[2:7]:
    nes_ls = df[i].values.tolist()
    avg = [sum(ls)/len(ls) for ls in nes_ls]
    new_df[i] = pd.Series(avg)
new_df['trainingsize'] = str(re.search(r'\d\d\d\d', file).group())

plot_df = plot_df.append(new_df)

# %%
file = RESULTS+'\\TRACE_results2703.json'
df = pd.read_json(file, lines=True)

new_df = pd.DataFrame(columns=df.columns[1:])
new_df['name'] = df.name

for i in df.columns[2:7]:
    nes_ls = df[i].values.tolist()
    avg = [sum(ls)/len(ls) for ls in nes_ls]
    new_df[i] = pd.Series(avg)
new_df['trainingsize'] = str(re.search(r'\d\d\d\d', file).group())

plot_df = plot_df.append(new_df)

# %%
file = RESULTS+'\\TRACE_results3809.json'
df = pd.read_json(file, lines=True)

new_df = pd.DataFrame(columns=df.columns[1:])
new_df['name'] = df.name

for i in df.columns[2:7]:
    nes_ls = df[i].values.tolist()
    avg = [sum(ls)/len(ls) for ls in nes_ls]
    new_df[i] = pd.Series(avg)
new_df['trainingsize'] = str(re.search(r'\d\d\d\d', file).group())

plot_df = plot_df.append(new_df)
plot_df.set_index('trainingsize', inplace=True)
plot_df
# Out:
#                                            name  accuracy  precision  \
# trainingsize
# 491           LogisticRegression (TruncatedSVD)  0.601417   0.651468
# 491                          LogisticRegression  0.603664   0.665319
# 491                SGDClassifier (TruncatedSVD)  0.629905   0.649171
# 491                               SGDClassifier  0.651275   0.647115
# 491                                         SVC  0.646999   0.647915
# 491                               MultinomialNB  0.578827   0.521206
# 491                   GaussianNB (TruncatedSVD)  0.559910   0.567111
# 1597          LogisticRegression (TruncatedSVD)  0.668372   0.677905
# 1597                         LogisticRegression  0.667949   0.677433
# 1597               SGDClassifier (TruncatedSVD)  0.678727   0.681723
# 1597                              SGDClassifier  0.677949   0.680360
# 1597                                        SVC  0.686675   0.684337
# 1597                              MultinomialNB  0.592074   0.706317
# 1597                  GaussianNB (TruncatedSVD)  0.425839   0.592226
# 2703          LogisticRegression (TruncatedSVD)  0.691146   0.689830
# 2703                         LogisticRegression  0.698268   0.697142
# 2703               SGDClassifier (TruncatedSVD)  0.688501   0.692695
# 2703                              SGDClassifier  0.686057   0.692374
# 2703                                        SVC  0.700510   0.702710
# 2703                              MultinomialNB  0.621773   0.687014
# 2703                  GaussianNB (TruncatedSVD)  0.574761   0.658398
# 3809          LogisticRegression (TruncatedSVD)  0.700713   0.697993
# 3809                         LogisticRegression  0.704577   0.703430
# 3809               SGDClassifier (TruncatedSVD)  0.697857   0.705805
# 3809                              SGDClassifier  0.691357   0.698997
# 3809                                        SVC  0.703151   0.706801
# 3809                              MultinomialNB  0.630311   0.687005
# 3809                  GaussianNB (TruncatedSVD)  0.617703   0.616995
#
#                 recall        f1        time
# trainingsize
# 491           0.601417  0.493949    3.107808
# 491           0.603664  0.497567    0.270864
# 491           0.629905  0.598323    3.090826
# 491           0.651275  0.639857    0.293888
# 491           0.646999  0.620390    0.417349
# 491           0.578827  0.426558    0.260440
# 491           0.559910  0.554262    3.163187
# 1597          0.668372  0.641949   10.691209
# 1597          0.667949  0.642120    0.612233
# 1597          0.678727  0.675241   10.446390
# 1597          0.677949  0.678139    0.638774
# 1597          0.686675  0.682631    1.841174
# 1597          0.592074  0.460799    0.593197
# 1597          0.425839  0.260537   10.413205
# 2703          0.691146  0.684602   15.765704
# 2703          0.698268  0.691629    1.009435
# 2703          0.688501  0.687273   15.801876
# 2703          0.686057  0.687595    0.865410
# 2703          0.700510  0.700541    3.803538
# 2703          0.621773  0.534458    0.818145
# 2703          0.574761  0.555110   14.258839
# 3809          0.700713  0.696539  144.322103
# 3809          0.704577  0.700749    1.449859
# 3809          0.697857  0.697534   21.834003
# 3809          0.691357  0.692903    1.334985
# 3809          0.703151  0.704090    7.924755
# 3809          0.630311  0.553701    1.263767
# 3809          0.617703  0.572383   22.430110

# %%
plot_df.groupby('name')['f1'].plot(legend=True)
# Out:
# name
# GaussianNB (TruncatedSVD)            AxesSubplot(0.125,0.125;0.775x0.755)
# LogisticRegression                   AxesSubplot(0.125,0.125;0.775x0.755)
# LogisticRegression (TruncatedSVD)    AxesSubplot(0.125,0.125;0.775x0.755)
# MultinomialNB                        AxesSubplot(0.125,0.125;0.775x0.755)
# SGDClassifier                        AxesSubplot(0.125,0.125;0.775x0.755)
# SGDClassifier (TruncatedSVD)         AxesSubplot(0.125,0.125;0.775x0.755)
# SVC                                  AxesSubplot(0.125,0.125;0.775x0.755)
# Name: f1, dtype: object

# %%
test = plot_df.groupby(['name'])
test.groups
# Out:
# {'GaussianNB (TruncatedSVD)': Index(['491', '1597', '2703', '3809'], dtype='object', name='trainingsize'),
#  'LogisticRegression': Index(['491', '1597', '2703', '3809'], dtype='object', name='trainingsize'),
#  'LogisticRegression (TruncatedSVD)': Index(['491', '1597', '2703', '3809'], dtype='object', name='trainingsize'),
#  'MultinomialNB': Index(['491', '1597', '2703', '3809'], dtype='object', name='trainingsize'),
#  'SGDClassifier': Index(['491', '1597', '2703', '3809'], dtype='object', name='trainingsize'),
#  'SGDClassifier (TruncatedSVD)': Index(['491', '1597', '2703', '3809'], dtype='object', name='trainingsize'),
#  'SVC': Index(['491', '1597', '2703', '3809'], dtype='object', name='trainingsize')}

# %%
#plot data
fig, ax = plt.subplots(figsize=(15,7))
plot_df.groupby(['name']).count()['f1'].unstack().plot(ax=ax)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-85-f417833c773b> in <module>
#       1 #plot data
#       2 fig, ax = plt.subplots(figsize=(15,7))
# ----> 3 plot_df.groupby(['name']).count()['f1'].unstack().plot(ax=ax)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\series.py in unstack(self, level, fill_value)
#    3743         from pandas.core.reshape.reshape import unstack
#    3744
# -> 3745         return unstack(self, level, fill_value)
#    3746
#    3747     # ----------------------------------------------------------------------
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\reshape\reshape.py in unstack(obj, level, fill_value)
#     421             level=level,
#     422             fill_value=fill_value,
# --> 423             constructor=obj._constructor_expanddim,
#     424         )
#     425         return unstacker.get_result()
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\reshape\reshape.py in __init__(self, values, index, level, value_columns, fill_value, constructor)
#     110             raise ValueError("must pass column labels for multi-column data")
#     111
# --> 112         self.index = index.remove_unused_levels()
#     113
#     114         self.level = self.index._get_level_number(level)
#
# AttributeError: 'Index' object has no attribute 'remove_unused_levels'

# %%
sub_df = df.drop('model', axis=1) 
sub_df
# Out:
#                                 name  \
# 0  LogisticRegression (TruncatedSVD)
# 1                 LogisticRegression
# 2       SGDClassifier (TruncatedSVD)
# 3                      SGDClassifier
# 4                                SVC
# 5                      MultinomialNB
# 6          GaussianNB (TruncatedSVD)
#
#                                             accuracy  \
# 0  [0.6000000000000001, 0.62, 0.6175, 0.54, 0.625...
# 1  [0.5875, 0.595, 0.6475000000000001, 0.65250000...
# 2  [0.625, 0.555, 0.6525000000000001, 0.645, 0.69...
# 3  [0.6900000000000001, 0.5875, 0.64, 0.58, 0.665...
# 4  [0.6325000000000001, 0.63, 0.615, 0.6325000000...
# 5  [0.5725, 0.58, 0.5975, 0.5650000000000001, 0.5...
# 6  [0.59, 0.54, 0.6125, 0.54, 0.5075000000000001,...
#
#                                            precision  \
# 0  [0.694066317626527, 0.6234078045874291, 0.7683...
# 1  [0.6440746753246751, 0.6571614583333331, 0.659...
# 2  [0.6300157889700481, 0.640229596444958, 0.6419...
# 3  [0.6814782608695651, 0.582383705821205, 0.6339...
# 4  [0.6222545454545451, 0.6490355477855471, 0.654...
# 5  [0.327756249999999, 0.757732997481108, 0.35939...
# 6  [0.59, 0.5672583915296231, 0.611412035169799, ...
#
#                                               recall  \
# 0  [0.6000000000000001, 0.62, 0.6175, 0.54, 0.625...
# 1  [0.5875, 0.595, 0.6475000000000001, 0.65250000...
# 2  [0.625, 0.555, 0.6525000000000001, 0.645, 0.69...
# 3  [0.6900000000000001, 0.5875, 0.64, 0.58, 0.665...
# 4  [0.6325000000000001, 0.63, 0.615, 0.6325000000...
# 5  [0.5725, 0.58, 0.5975, 0.5650000000000001, 0.5...
# 6  [0.59, 0.54, 0.6125, 0.54, 0.5075000000000001,...
#
#                                                   f1  \
# 0  [0.488386540120793, 0.52600819586004, 0.499150...
# 1  [0.479648079399954, 0.478128611957549, 0.55218...
# 2  [0.6039225260416661, 0.5205354140395121, 0.639...
# 3  [0.67909381663113, 0.562760318773024, 0.625482...
# 4  [0.622422074603985, 0.598403913347309, 0.56187...
# 5  [0.416860095389507, 0.43359920678638303, 0.448...
# 6  [0.59, 0.545217259804415, 0.605988965410806, 0...
#
#                                                 time
# 0  [2.889954805374145, 1.76901364326477, 1.708637...
# 1  [0.19299483299255302, 0.19332432746887201, 0.2...
# 2  [1.951280832290649, 1.8932464122772212, 2.0803...
# 3  [0.193212747573852, 0.18088912963867101, 0.174...
# 4  [0.406158208847045, 0.46690559387207003, 0.403...
# 5  [0.31012487411499, 0.20503854751586903, 0.2298...
# 6  [2.671550512313842, 2.484850168228149, 2.34996...

# %%
df_lists = sub_df[['accuracy','precision','recall','f1','time']].unstack().apply(pd.Series)

# %%
score = 'f1'
plot_data = df_lists.T[score]
plot_data.columns = list(df.name)
plot_data.index = range(1,13)
plot_data
# Out:
#     LogisticRegression (TruncatedSVD)  LogisticRegression  \
# 1                            0.488387            0.479648
# 2                            0.526008            0.478129
# 3                            0.499151            0.552187
# 4                            0.410185            0.556901
# 5                            0.519183            0.437315
# 6                            0.529031            0.473562
# 7                            0.473659            0.468474
# 8                            0.452189            0.530222
# 9                            0.465589            0.464600
# 10                           0.528167            0.389789
# 11                           0.429985            0.462008
# 12                           0.461284            0.503511
#
#     SGDClassifier (TruncatedSVD)  SGDClassifier       SVC  MultinomialNB  \
# 1                       0.603923       0.679094  0.622422       0.416860
# 2                       0.520535       0.562760  0.598404       0.433599
# 3                       0.639310       0.625483  0.561875       0.448826
# 4                       0.604294       0.559201  0.604155       0.415790
# 5                       0.664791       0.655648  0.613565       0.393007
# 6                       0.599070       0.658948  0.619413       0.453050
# 7                       0.580305       0.651880  0.631785       0.413885
# 8                       0.642894       0.622332  0.648651       0.401784
# 9                       0.601761       0.632535  0.684707       0.452626
# 10                      0.645642       0.606244  0.597965       0.455673
# 11                      0.568279       0.620679  0.641169       0.416860
# 12                      0.659857       0.633172  0.626699       0.409438
#
#     GaussianNB (TruncatedSVD)
# 1                    0.590000
# 2                    0.545217
# 3                    0.605989
# 4                    0.545128
# 5                    0.504745
# 6                    0.583457
# 7                    0.620722
# 8                    0.548752
# 9                    0.536570
# 10                   0.550647
# 11                   0.569283
# 12                   0.580885

# %%
import pandas as pd
import numpy as np
# %matplotlib inline 
plt.rcParams['figure.figsize'] = [10, 5]
#f, ax = plt.subplots()
ax = plot_data.plot(style='.-')
plt.ylabel(score)
plt.xlabel('CV fold')
plt.ylim(.40,1)
plt.title('{} score of each classifier over CV fold on (1,2) gram model'.format(score, gram))
# plt.show()
plt.savefig(PLOTS+'\\f1_1n2g.png', bbox_inches='tight')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-ece1279a5979> in <module>
#       8 plt.xlabel('CV fold')
#       9 plt.ylim(.40,1)
# ---> 10 plt.title('{} score of each classifier over CV fold on (1,2) gram model'.format(score, gram))
#      11 # plt.show()
#      12 plt.savefig(PLOTS+'\\f1_1n2g.png', bbox_inches='tight')
#
# NameError: name 'gram' is not defined

# %%
df.name
# Out:
# 0    LogisticRegression (TruncatedSVD)
# 1                   LogisticRegression
# 2         SGDClassifier (TruncatedSVD)
# 3                        SGDClassifier
# 4                        MultinomialNB
# 5            GaussianNB (TruncatedSVD)
# Name: name, dtype: object
