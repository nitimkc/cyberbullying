# %%
import os
import json
import re
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt

# %%
os.getcwd()
# Out:
# 'C:\\Users\\niti.mishra\\Documents\\Personal\\cyberbullying'

# %%
def plot_cv(file, ngram, labelset, show=False
           ):
    
    df = pd.read_json(file, lines=True)

    acc = pd.DataFrame(df['f1_valid'].values.tolist(), index=df.name)
    print(acc.mean(axis=1))
    
    f1_v = pd.DataFrame(df['f1_valid'].values.tolist(), index=df.name)
    fig, ax = plt.subplots(figsize=(10,5))
    f1_v.T.plot(ax=ax)
    ax.set_xlabel('K-fold')
    ax.set_ylabel('f1 score')
    fig.suptitle('f1 score of each classifier over CV fold on ' + ngram + ' gram model with labels from ' +
                 labelset, fontsize=15)
#     plt.show()
    plt.savefig(i.stem+'.png')
    
    if show:
        return df

# %%
ROOT = 'C:\\Users\\niti.mishra\\Documents\\Personal\\cyberbullying\\'
# RESULTS = Path(os.path.join(ROOT, 'results'))
RESULTS = Path(os.path.join(ROOT, 'results\\1g2g'))
PLOTS = Path(os.path.join(RESULTS))
files = [i for i in list(RESULTS.iterdir()) if '.json' in i.suffix ]
files
# Out:
# [WindowsPath('C:/Users/niti.mishra/Documents/Personal/cyberbullying/results/1g2g/FORM_results2467_1g2g_ab.json'),
#  WindowsPath('C:/Users/niti.mishra/Documents/Personal/cyberbullying/results/1g2g/ROLE_results2265_1g2g_ab.json'),
#  WindowsPath('C:/Users/niti.mishra/Documents/Personal/cyberbullying/results/1g2g/TRACE_results3837_1g2g_ab.json'),
#  WindowsPath('C:/Users/niti.mishra/Documents/Personal/cyberbullying/results/1g2g/TYPE_results2427_1g2g_ab.json')]

# %%
for i in files:
    print(i.stem)
    plot_cv(file, ngram='(1,2)', labelset='ab')
# Out:
# FORM_results2467_1g2g_ab
# name
# LogisticRegression      0.531848
# SVC                     0.546191
# KNeighborsClassifier    0.431502
# dtype: float64
# ROLE_results2265_1g2g_ab
# name
# LogisticRegression      0.531848
# SVC                     0.546191
# KNeighborsClassifier    0.431502
# dtype: float64
# TRACE_results3837_1g2g_ab
# name
# LogisticRegression      0.531848
# SVC                     0.546191
# KNeighborsClassifier    0.431502
# dtype: float64
# TYPE_results2427_1g2g_ab
# name
# LogisticRegression      0.531848
# SVC                     0.546191
# KNeighborsClassifier    0.431502
# dtype: float64
